# %%
# !pip install -qqq -U git+https://github.com/huggingface/transformers --progress-bar off
# !pip install -qqq -U torch==2.2.1 transformers datasets accelerate peft trl bitsandbytes wandb --progress-bar off
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# # Load configurations from YAML file through google drive to get access token
from google.colab import drive
import yaml
drive.mount('/content/drive')

CONFIG_PATH = './drive/MyDrive/cpsc477/config.yaml'

def load_config(config_path):
        with open(config_path, 'r') as file:
            return yaml.safe_load(file)

## load configurations
config = load_config(CONFIG_PATH)
hf_token = config['access_token']['hf_token']
hf_token_write = config['access_token']['hf_token_write']
wb_token = config['access_token']['wb_token']
# Out:
# Mounted at /content/drive

# %%
import torch
major_version, minor_version = torch.cuda.get_device_capability()
# Must install separately since Colab has torch 2.2.1, which breaks packages
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # Use this for new GPUs like Ampere, Hopper GPUs (RTX 30xx, RTX 40xx, A100, H100, L40)
    # !pip install -qqq -U --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes --progress-bar off
else:
    # Use this for older GPUs (V100, Tesla T4, RTX 20xx)
    # !pip install -qqq -U --no-deps xformers trl peft accelerate bitsandbytes --progress-bar off
pass
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-_2lo3c9k/unsloth_214de03d4fb545b0adf08a9b8f1afecc
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-_2lo3c9k/unsloth_214de03d4fb545b0adf08a9b8f1afecc
#   Resolved https://github.com/unslothai/unsloth.git to commit 4211cc01409e3ced4f7abebaf68e244193b46e2c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for unsloth: filename=unsloth-2024.4-py3-none-any.whl size=101150 sha256=9e17d785ccf8884874e290698c22f6ef2d9e03e5246f6e3975b14f899f121914
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ifh9dg2/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8B-instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = True # Use 4bit quantization
)
# Out:
# WARNING:xformers:WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.3.0+cu121 with CUDA 1201 (you have 2.2.1+cu121)
#     Python  3.10.14 (you have 3.10.12)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.4
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("yl2342/friends_chandler_bing_sarcasm",
                       "instruct", # subset
                       split = "train")

# dataset = dataset.map(format_prompt)

print(dataset[0])
# Out:
# ...
# Generating train split:   0%|          | 0/1978 [00:00<?, ? examples/s]
# {'text': "<s>[INST]You are a helpful AI assistant who will act like Chandler Bing, the witty and sarcastic character from the TV sitcom Friends who has unique sense of humor and tendency to make jokes and use sarcasm. Given the context provided below, please respond in the style of Chandler Bing. Context: Joey pressures Monica to share details about a man she's going out with, implying something must be wrong with him. Joey: C'mon, you're going out with the guy! There's gotta be something wrong with him![/INST]All right Joey, be nice. So does he have a hump? A hump and a hairpiece?</s>"}

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 321
    # use_rslora = False,
    # loftq_config = None,
)
# Out:
# Unsloth 2024.4 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
import wandb
wandb.login(key = wb_token)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from transformers import TrainingArguments
from trl import SFTTrainer
import wandb

project_name = "llama3-8bing-sft"
entity = "wandb"
wandb.init(project=project_name, name = "llama-3-8bing-sft")

# sft_trainer = SFTTrainer(
#     model = model,
#     args = TrainingArguments(
#         per_device_train_batch_size = 2,
#         gradient_accumulation_steps = 4,
#         warmup_ratio = 0.1,
#         num_train_epochs = 1,
#         learning_rate = 5e-5,
#         fp16 = not torch.cuda.is_bf16_supported(),
#         bf16 = torch.cuda.is_bf16_supported(),
#         logging_steps = 10,
#         # max_steps= 100,
#         optim = "adamw_8bit",
#         weight_decay = 0.001,
#         lr_scheduler_type = "linear",
#         seed = 321,
#         report_to="wandb",  # enable logging to W&B
#         output_dir = "outputs"
#     ),
#     train_dataset = dataset,
#     dataset_text_field = "text",
#     tokenizer = tokenizer,
#     max_seq_length = 1024
# )


sft_trainer = SFTTrainer(
    model = model,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = 1024,
    tokenizer = tokenizer,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_ratio = 0.1,
        num_train_epochs = 1,
        learning_rate = 5e-5,
        # max_steps = 60,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 10,
        weight_decay = 0.001,
        optim = "adamw_8bit",
        lr_scheduler_type = "linear",
        seed = 321,
        report_to="wandb",  # enable logging to W&B
        output_dir = "outputs"
    )
)
# Out:
# wandb: Currently logged in as: yl2342. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/content/wandb/run-20240508_052452-wn8rjls6</code>
# Syncing run <strong><a href='https://wandb.ai/yl2342/llama3-8bing-sft/runs/wn8rjls6' target="_blank">llama-3-8bing-sft</a></strong> to <a href='https://wandb.ai/yl2342/llama3-8bing-sft' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yl2342/llama3-8bing-sft' target="_blank">https://wandb.ai/yl2342/llama3-8bing-sft</a>
#  View run at <a href='https://wandb.ai/yl2342/llama3-8bing-sft/runs/wn8rjls6' target="_blank">https://wandb.ai/yl2342/llama3-8bing-sft/runs/wn8rjls6</a>
# Map:   0%|          | 0/1978 [00:00<?, ? examples/s]

# %%
sft_trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 1,978 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 247
#  "-____-"     Number of trainable parameters = 83,886,080
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#     <div>
#
#       <progress value='247' max='247' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [247/247 07:28, Epoch 0/1]
#     </div>
# ...

# %%
# Saving models to 16bit for VLLM
model.push_to_hub_merged("yl2342/llama3-8bing-sft",
                         tokenizer,
                         save_method = "merged_16bit",
                         token = hf_token_write)
# Out:
# Unsloth: You are pushing to hub, but you passed your HF username = yl2342.
# We shall truncate yl2342/llama3-8bing-sft to llama3-8bing-sft
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 5.7G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 63.33 out of 83.48 RAM for saving.
# 100%|██████████| 32/32 [00:00<00:00, 53.93it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# README.md:   0%|          | 0.00/591 [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# ...

# %%
model.save_pretrained("llama3-8bing-sft")

from unsloth import FastLanguageModel
model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "llama3-8bing-sft",
        max_seq_length = 512,
        # dtype = dtype,
        load_in_4bit = True,
    )

FastLanguageModel.for_inference(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.4
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = True.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# ...

# %%
import transformers
message = [
    {"role": "system", "content": "You are a helpful AI assistant who will act like Chandler Bing, the witty and sarcastic character from the TV sitcom Friends who has unique sense of humor and tendency to make jokes and use sarcasm. Given the context provided below, please respond in the style of Chandler Bing."},
    {"role": "user", "content": "Context: Ross is upset about someone eating his sandwich at work and Chandler responds with a question implying the situation is overly dramatic."}
]

prompt = tokenizer.apply_chat_template(message, add_generation_prompt=True, tokenize=False)

# Create pipeline
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

# Generate text
sequences = pipeline(
    prompt,
    do_sample=True,
    temperature=1.2,
    top_p=0.9,
    eos_token_id=terminators,
    num_return_sequences=1,
    max_length=256,
)

print(sequences[0]['generated_text'][len(prompt):])
# Out:
# Could this possibly be any worse?!

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 10.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 59.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

messages = []

def add_text(history, text):
    global messages  #message[list] is defined globally
    history = history + [(text,'')]
    messages = messages + [{"role":'user', 'content': text}]
    return history, ""

def generate(history):
  global messages
  prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

  terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

  outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)
  response_msg = outputs[0]["generated_text"][len(prompt):]
  for char in response_msg:
      history[-1][1] += char
      yield history
  pass


with gr.Blocks() as demo:

    chatbot = gr.Chatbot(value=[], elem_id="sarcastic chatbot - llama3-8-Bing")
    with gr.Row():
            txt = gr.Textbox(
                show_label=False,
                placeholder="Enter text and press enter",
            )

    txt.submit(add_text, [chatbot, txt], [chatbot, txt], queue=False).then(
            generate, inputs =[chatbot,],outputs = chatbot,)

demo.queue()
demo.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://a47c11d2829f7adf0e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a47c11d2829f7adf0e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://a47c11d2829f7adf0e.gradio.live
